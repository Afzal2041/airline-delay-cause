# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Airline_Delay_Cause.csv')
df.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE
# 1  2022      5      9E  Endeavor Air Inc.     ABY
# 2  2022      5      9E  Endeavor Air Inc.     ACK
# 3  2022      5      9E  Endeavor Air Inc.     AEX
# 4  2022      5      9E  Endeavor Air Inc.     AGS
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0        7.0
# 1             Albany, GA: Southwest Georgia Regional         91.0       16.0
# 2                  Nantucket, MA: Nantucket Memorial         19.0        2.0
# 3           Alexandria, LA: Alexandria International         88.0       14.0
# 4        Augusta, GA: Augusta Regional at Bush Field        181.0       19.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        5.95        0.00  ...          0.0              1.00            0.0
# ...

# %%
df.shape
# Out:
# (318017, 21)

# %%
df.columns
# Out:
# Index(['year', 'month', 'carrier', 'carrier_name', 'airport', 'airport_name',
#        'arr_flights', 'arr_del15', 'carrier_ct', 'weather_ct', 'nas_ct',
#        'security_ct', 'late_aircraft_ct', 'arr_cancelled', 'arr_diverted',
#        'arr_delay', 'carrier_delay', 'weather_delay', 'nas_delay',
#        'security_delay', 'late_aircraft_delay'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318017 entries, 0 to 318016
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   year                 318017 non-null  int64
#  1   month                318017 non-null  int64
#  2   carrier              318013 non-null  object
#  3   carrier_name         318013 non-null  object
#  4   airport              318014 non-null  object
#  5   airport_name         318017 non-null  object
#  6   arr_flights          317524 non-null  float64
#  7   arr_del15            317285 non-null  float64
#  8   carrier_ct           317525 non-null  float64
#  9   weather_ct           317523 non-null  float64
#  10  nas_ct               317529 non-null  float64
#  11  security_ct          317529 non-null  float64
#  12  late_aircraft_ct     317529 non-null  float64
#  13  arr_cancelled        317529 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 year          month    arr_flights      arr_del15  \
# count  318017.000000  318017.000000  317524.000000  317285.000000
# mean     2012.450957       6.497844     381.766670      72.905076
# std         5.678296       3.459423    1027.156722     198.936754
# min      2003.000000       1.000000       1.000000       0.000000
# 25%      2007.000000       3.000000      59.000000       9.000000
# 50%      2012.000000       6.000000     120.000000      23.000000
# 75%      2018.000000      10.000000     273.000000      56.000000
# max      2022.000000      12.000000   21977.000000    6377.000000
#
#           carrier_ct     weather_ct         nas_ct    security_ct  \
# count  317525.000000  317523.000000  317529.000000  317529.000000
# mean       21.073149       2.616407      24.005228       0.179037
# std        47.671580       9.968640      85.113757       0.844834
# min         0.000000       0.000000      -0.010000       0.000000
# ...

# %%
df.groupby("carrier_name")["arr_delay"].sum().sort_values(ascending=False)
# Out:
# carrier_name
# Southwest Airlines Co.          197589768.0
# American Airlines Inc.          158749715.0
# SkyWest Airlines Inc.           126613903.0
# Delta Air Lines Inc.            125895285.0
# United Air Lines Inc.           114178620.0
# ExpressJet Airlines Inc.         98092859.0
# American Eagle Airlines Inc.     64423618.0
# JetBlue Airways                  62862075.0
# US Airways Inc.                  48308565.0
# Atlantic Southeast Airlines      36380279.0
# Mesa Airlines Inc.               31835872.0
# Continental Air Lines Inc.       30000006.0
# Northwest Airlines Inc.          29540965.0
# AirTran Airways Corporation      27309982.0
# Alaska Airlines Inc.             26883351.0
# Frontier Airlines Inc.           21876820.0
# Comair Inc.                      21168261.0
# Envoy Air                        18567639.0
# Spirit Air Lines                 16425171.0
# Republic Airline                 12921846.0
# Pinnacle Airlines Inc.           12599148.0
# ...

# %%
df["weather_delay"].sum()
# Out:
# np.float64(70036591.0)

# %%
df.groupby("airport_name")["arr_delay"].sum().sort_values(ascending=False).head(10)
# Out:
# airport_name
# Chicago, IL: Chicago O'Hare International                 89293573.0
# Atlanta, GA: Hartsfield-Jackson Atlanta International     81599533.0
# Dallas/Fort Worth, TX: Dallas/Fort Worth International    59430306.0
# Newark, NJ: Newark Liberty International                  47297459.0
# San Francisco, CA: San Francisco International            43642990.0
# Denver, CO: Denver International                          43004336.0
# Los Angeles, CA: Los Angeles International                40605274.0
# Houston, TX: George Bush Intercontinental/Houston         34201365.0
# New York, NY: LaGuardia                                   33661573.0
# New York, NY: John F. Kennedy International               29812161.0
# Name: arr_delay, dtype: float64

# %%
df.groupby("year")["arr_delay"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='year'>
